# %% [markdown]
# # setup.ipynb
#
# This notebook initializes the project environment for the Small Data NER project.
#
# It performs the following steps:
# 1. Mounts Google Drive.
# 2. Creates the project folder structure if missing:
#    - raw/: original E3C data
#    - conll/: train/dev/test and few-shot splits
#    - utils/: helper scripts (conll_io.py, metrics.py)
#    - notebooks for preprocessing, model training, and evaluation
# 3. Installs required Python packages.
# 4. Verifies that all files and paths are accessible.
#
# After running setup.ipynb once, all team members can open other notebooks directly (e.g., preprocessing.ipynb, prompting.ipynb).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !rm -rf .git
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/small_data_NER_project
# !printf "%s\n" \
"__pycache__/" \
"*.ipynb_checkpoints/" \
"*.gdoc" "*.gsheet" "*.tmp" \
"wandb/" \
"*.bin" "*.pt" "*.safetensors" \
".DS_Store" \
".config/" "sample_data/" > .gitignore
# Out:
# /content/drive/MyDrive/small_data_NER

# %%
import os

base_path = "/content/drive/MyDrive/small_data_NER_project"

# Define project subfolders
subfolders = [
    "raw",
    "conll",
    "utils",
    "results"
]

# Create directories
for sub in subfolders:
    os.makedirs(os.path.join(base_path, sub), exist_ok=True)

# Install basic dependencies
# !pip install transformers datasets seqeval peft accelerate -q

# Verify structure
print("Project structure:")
for root, dirs, files in os.walk(base_path):
    level = root.replace(base_path, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = ' ' * 4 * (level + 1)
    for f in files:
        print(f"{subindent}{f}")

print("\nSetup complete.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
# Project structure:
# small_data_NER/
#     setup.ipynb
#     .gitattributes
#     preprocessing.ipynb
#     .gitignore
#     biobert_baseline.ipynb
#     .git/
#         description
#         packed-refs
#         index
#         HEAD
#         config
#         hooks/
#             applypatch-msg.sample
#             prepare-commit-msg.sample
#             pre-rebase.sample
#             post-update.sample
#             commit-msg.sample
#             pre-applypatch.sample
#             pre-receive.sample
#             pre-push.sample
#             fsmonitor-watchman.sample
#             pre-merge-commit.sample
#             pre-commit.sample
#             sendemail-validate.sample
#             push-to-checkout.sample
#             update.sample
#         refs/
#             heads/
#                 main
#             remotes/
#                 origin/
#                     HEAD
#         info/
#             exclude
#         logs/
#             HEAD
#             refs/
#                 heads/
#                     main
#                 remotes/
#                     origin/
#                         HEAD
#         objects/
#             pack/
#                 pack-64978ed081f9a7514760fca51096b6cf5f7b86bd.rev
#                 pack-64978ed081f9a7514760fca51096b6cf5f7b86bd.pack
#                 pack-64978ed081f9a7514760fca51096b6cf5f7b86bd.idx
#     results/
#         biobert_k5_full/
#             metrics.json
#             checkpoint-10/
#                 trainer_state.json
#                 vocab.txt
#                 special_tokens_map.json
#                 config.json
#                 tokenizer.json
#                 rng_state.pth
#                 tokenizer_config.json
#             checkpoint-1/
#                 trainer_state.json
#                 tokenizer_config.json
#                 rng_state.pth
#                 special_tokens_map.json
#                 vocab.txt
#                 tokenizer.json
#                 config.json
#             logs/
#                 events.out.tfevents.1759872330.a6671d08f5a8.3663.4
#                 events.out.tfevents.1759871765.a6671d08f5a8.3663.0
#                 events.out.tfevents.1759873026.2442290a3a23.1766.0
#                 events.out.tfevents.1759873091.2442290a3a23.1766.1
#                 events.out.tfevents.1759871875.a6671d08f5a8.3663.1
#                 events.out.tfevents.1759872199.a6671d08f5a8.3663.3
#                 events.out.tfevents.1759872151.a6671d08f5a8.3663.2
#     raw/
#         English/
#             train.txt
#             test.txt
#     utils/
#         metrics.py
#         conll_io.py
#     conll/
#         dev.conll
#         test.conll
#         train.conll
#         fewshot_k10_seed42_mention/
#             train.conll
#             dev.conll
#             test.conll
#         fewshot_k1_seed42_sent/
#             test.conll
#             dev.conll
#             train.conll
#         fewshot_k10_seed42_sent/
#             train.conll
#             test.conll
#             dev.conll
#         fewshot_k5_seed42_mention/
#             dev.conll
#             test.conll
#             train.conll
#         fewshot_k20_seed42_sent/
#             train.conll
#             dev.conll
#             test.conll
#         fewshot_k5_seed42_sent/
#             train.conll
#             dev.conll
#             test.conll
#         fewshot_k20_seed42_mention/
#             dev.conll
#             test.conll
#             train.conll
#         fewshot_k1_seed42_mention/
#             dev.conll
#             train.conll
#             test.conll
#
# Setup complete.
